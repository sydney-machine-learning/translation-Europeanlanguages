# %%
# %pip install openai
# Out:
# Collecting openai
#   Downloading openai-2.36.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from openai) (4.12.1)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.14.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Requirement already satisfied: sniffio in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from openai) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.46.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading openai-2.36.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.6 MB/s  0:00:00m eta 0:00:01
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.14.0-cp310-cp310-macosx_11_0_arm64.whl (321 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 2.7 MB/s  0:00:00 eta 0:00:01
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, jiter, distro, annotated-types, pydantic, openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [openai]2m6/7 [openai]
# Successfully installed annotated-types-0.7.0 distro-1.9.0 jiter-0.14.0 openai-2.36.0 pydantic-2.13.4 pydantic-core-2.46.4 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#CSV Vers.
from openai import OpenAI
from time import sleep
import os
#import glob
import pandas as pd

client = OpenAI(api_key="") #api key here

INPUT_FILE = "BTA_news_combined_master_bul.csv"
INPUT_DIR = "Data/Bulgarian/BulgarianNews/bul_origianl_BTA_news"
OUTPUT_DIR = "Data/Bulgarian/BulgarianNews/gpt_IPN_news"
OUTPUT_CSV = "BTA_news_combined_master_gpt.csv"

def translate_text(text, model):
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": "You are a professional translator，please translate from Bulgarian to English while preserving the Markdown structure and formatting."},
                {"role": "user", "content": f"Please translate the following Bulgarian content：{text}"}
            ],
            temperature=0.3 #lower --> more consistent, literal output
        )
        translated_content = response.choices[0].message.content
        return translated_content.replace("Please translate the following Bulgarian content:", "").strip()
    
    except Exception as e:
        print(f"Translation error: {e}")
        return ""

def translate_csv(model="gpt-5.4-mini"):
    df = pd.read_csv(os.path.join(INPUT_DIR, INPUT_FILE))
    
    translations = []

    print(f"Loaded {len(df)} rows from {INPUT_FILE}")
    print(f"Using model: {model}")

    for i, text in enumerate(df['Content'], 1):
        print(f"Translating row {i}/{len(df)}")

        if pd.isna(text) or not str(text).strip():
            translations.append("")
            continue

        translated_content = translate_text(str(text), model)
        translations.append(translated_content)

        sleep(1)

    df["Translated Content"] = translations
    df.to_csv(os.path.join(OUTPUT_DIR, OUTPUT_CSV), index = False)
    print(f"\n Saved translated CSV: {OUTPUT_CSV}")

    return df


if __name__ == "__main__":

    translate_csv(model="gpt-5.4-mini")
# Out:
# Loaded 91 rows from BTA_news_combined_master_bul.csv
# Using model: gpt-5.4-mini
# Translating row 1/91
# Translating row 2/91
# Translating row 3/91
# Translating row 4/91
# Translating row 5/91
# Translating row 6/91
# Translating row 7/91
# Translating row 8/91
# Translating row 9/91
# Translating row 10/91
# Translating row 11/91
# Translating row 12/91
# Translating row 13/91
# Translating row 14/91
# Translating row 15/91
# Translating row 16/91
# Translating row 17/91
# Translating row 18/91
# Translating row 19/91
# Translating row 20/91
# Translating row 21/91
# Translating row 22/91
# Translating row 23/91
# Translating row 24/91
# Translating row 25/91
# Translating row 26/91
# Translating row 27/91
# Translating row 28/91
# Translating row 29/91
# Translating row 30/91
# Translating row 31/91
# Translating row 32/91
# Translating row 33/91
# Translating row 34/91
# Translating row 35/91
# Translating row 36/91
# Translating row 37/91
# Translating row 38/91
# Translating row 39/91
# Translating row 40/91
# Translating row 41/91
# Translating row 42/91
# Translating row 43/91
# Translating row 44/91
# Translating row 45/91
# Translating row 46/91
# Translating row 47/91
# Translating row 48/91
# Translating row 49/91
# Translating row 50/91
# Translating row 51/91
# Translating row 52/91
# Translating row 53/91
# Translating row 54/91
# Translating row 55/91
# Translating row 56/91
# Translating row 57/91
# Translating row 58/91
# Translating row 59/91
# Translating row 60/91
# Translating row 61/91
# Translating row 62/91
# Translating row 63/91
# Translating row 64/91
# Translating row 65/91
# Translating row 66/91
# Translating row 67/91
# Translating row 68/91
# Translating row 69/91
# Translating row 70/91
# Translating row 71/91
# Translating row 72/91
# Translating row 73/91
# Translating row 74/91
# Translating row 75/91
# Translating row 76/91
# Translating row 77/91
# Translating row 78/91
# Translating row 79/91
# Translating row 80/91
# Translating row 81/91
# Translating row 82/91
# Translating row 83/91
# Translating row 84/91
# Translating row 85/91
# Translating row 86/91
# Translating row 87/91
# Translating row 88/91
# Translating row 89/91
# Translating row 90/91
# Translating row 91/91
#
#  Saved translated CSV: BTA_news_combined_master_gpt.csv

# %%
#MD vers.
from openai import OpenAI
from time import sleep
import os
import glob

client = OpenAI(api_key="") #api key here

INPUT_DIR = "1tv_news_articles_ge"
OUTPUT_DIR = "1tv_news_articles_gpt"

def translate_text(text, model="gpt-5.4-mini"):
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": "You are a professional translator，please translate from Georgian to English while preserving the Markdown structure and formatting."},
                {"role": "user", "content": f"Please translate the following Georgian content：{text}"}
            ],
            temperature=0.3 #lower --> more consistent, literal output
        )
        translated_content = response.choices[0].message.content
        return translated_content.replace("Please translate the following Georgian content:", "").strip()
    
    except Exception as e:
        print(f"Translation error: {e}")
        return ""

def translate_single_file(input_file, output_file, model="gpt-5.4-mini"):

    print(f"\n Starting to process files: {os.path.basename(input_file)}")

    with open(input_file, "r", encoding = "utf-8") as f:
        content = f.read()

    if not content.strip():
        print("  File is empty.")
        return

    translated_content = translate_text(content, model)

    with open(output_file, "w", encoding = "utf-8") as f:
        f.write(translated_content)

    print(f"  Saved translated file: {os.path.basename(output_file)}")


def translate_all_files(model="gpt-5.4-mini"):

    #Create output directory if it doesn't exist
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # Find all files
    pattern = os.path.join(INPUT_DIR, "*.md")
    files = glob.glob(pattern)
    
    if not files:
        print(f"No file found！Please check directory: {INPUT_DIR}")
        return
    
    print(f"Found {len(files)} files to translate")
    print(f"Using model: {model}")
    
    for i, input_file in enumerate(files, 1):
        print(f"\n========== Processing {i}/{len(files)} files ==========")
        
        # Create file names
        base_name = os.path.basename(input_file)
        output_name = base_name.replace('.md', f'_{model}_translated.md')
        output_file = os.path.join(OUTPUT_DIR, output_name)
        
        # Translate file
        translate_single_file(input_file, output_file, model)

        sleep(1)
        
    print(f"\n All files translated！Saved at: {OUTPUT_DIR}")


if __name__ == "__main__":

    translate_all_files(model="gpt-5.4-mini")

# %%
# %pip install -U google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-2.0.1-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-genai) (4.12.1)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading google_auth-2.52.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-genai) (2.32.5)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<17.0,>=13.0.0 (from google-genai)
#   Downloading websockets-16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading cryptography-48.0.0-cp39-abi3-macosx_10_9_universal2.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Using cached cffi-2.0.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Using cached pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading google_genai-2.0.1-py3-none-any.whl (791 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 791.4/791.4 kB 1.8 MB/s  0:00:0036m-:--:--
# Downloading google_auth-2.52.0-py3-none-any.whl (245 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading websockets-16.0-cp310-cp310-macosx_11_0_arm64.whl (175 kB)
# Downloading cryptography-48.0.0-cp39-abi3-macosx_10_9_universal2.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 970.3 kB/s  0:00:08m0:00:0100:01
# Using cached cffi-2.0.0-cp310-cp310-macosx_11_0_arm64.whl (180 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: websockets, tenacity, pycparser, pyasn1, pyasn1-modules, cffi, cryptography, google-auth, google-genai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [google-genai] [google-genai]
# Successfully installed cffi-2.0.0 cryptography-48.0.0 google-auth-2.52.0 google-genai-2.0.1 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0 tenacity-9.1.4 websockets-16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#CSV vers.
from google import genai
from google.genai import types
from time import sleep
import os
#import glob
import pandas as pd

client = genai.Client(api_key="") #api key here 

INPUT_DIR = "Data/Bulgarian/BulgarianNews/bul_origianl_BTA_news"
INPUT_FILE = "BTA_news_combined_master_bul.csv"
OUTPUT_DIR = "Data/Bulgarian/BulgarianNews/gem_BTA_news"
OUTPUT_CSV = "BTA_news_combined_master_gem.csv"

def translate_text(text, model="gemini-3-flash-preview"):
    try:
        response = client.models.generate_content(
            model=model,
            contents=f"Please translate the following Bulgarian content：{text}",
            config=types.GenerateContentConfig(
                temperature=0.3,
                system_instruction="You are a professional translator，please translate from Bulgarian to English while preserving the Markdown structure and formatting.",
            )
        )
        translated_content = response.text if response.text else ""
        return translated_content.replace("Please translate the following Bulgarian content:", "").strip()
    
    except Exception as e:
        print(f"Translation error: {e}")
        return ""

def translate_csv(model):
    df = pd.read_csv(os.path.join(INPUT_DIR, INPUT_FILE))
    
    translations = []

    print(f"Loaded {len(df)} rows from {INPUT_FILE}")
    print(f"Using model: {model}")

    for i, text in enumerate(df['Content'], 1):
        print(f"Translating row {i}/{len(df)}")

        if pd.isna(text) or not str(text).strip():
            translations.append("")
            continue

        translated_content = translate_text(str(text), model)
        translations.append(translated_content)

        sleep(1)

    df["Translated Content"] = translations
    df.to_csv(os.path.join(OUTPUT_DIR, OUTPUT_CSV), index = False)
    print(f"\n Saved translated CSV: {OUTPUT_CSV}")

    return df


if __name__ == "__main__":

    translate_csv(model="gemini-3-flash-preview")
# Out:
# Loaded 91 rows from BTA_news_combined_master_bul.csv
# Using model: gemini-3-flash-preview
# Translating row 1/91
# Translating row 2/91
# Translating row 3/91
# Translating row 4/91
# Translating row 5/91
# Translating row 6/91
# Translating row 7/91
# Translating row 8/91
# Translating row 9/91
# Translating row 10/91
# Translating row 11/91
# Translating row 12/91
# Translating row 13/91
# Translating row 14/91
# Translating row 15/91
# Translating row 16/91
# Translating row 17/91
# Translating row 18/91
# Translating row 19/91
# Translating row 20/91
# Translating row 21/91
# Translating row 22/91
# Translating row 23/91
# Translating row 24/91
# Translating row 25/91
# Translating row 26/91
# Translating row 27/91
# Translating row 28/91
# Translating row 29/91
# Translating row 30/91
# Translating row 31/91
# Translating row 32/91
# Translating row 33/91
# Translating row 34/91
# Translating row 35/91
# Translating row 36/91
# Translating row 37/91
# Translating row 38/91
# Translating row 39/91
# Translating row 40/91
# Translating row 41/91
# Translating row 42/91
# Translating row 43/91
# Translating row 44/91
# Translating row 45/91
# Translating row 46/91
# Translating row 47/91
# Translating row 48/91
# Translating row 49/91
# Translating row 50/91
# Translating row 51/91
# Translating row 52/91
# Translating row 53/91
# Translating row 54/91
# Translating row 55/91
# Translating row 56/91
# Translating row 57/91
# Translating row 58/91
# Translating row 59/91
# Translating row 60/91
# Translating row 61/91
# Translating row 62/91
# Translating row 63/91
# Translating row 64/91
# Translating row 65/91
# Translating row 66/91
# Translating row 67/91
# Translating row 68/91
# Translating row 69/91
# Translating row 70/91
# Translating row 71/91
# Translating row 72/91
# Translating row 73/91
# Translating row 74/91
# Translating row 75/91
# Translating row 76/91
# Translating row 77/91
# Translating row 78/91
# Translating row 79/91
# Translating row 80/91
# Translating row 81/91
# Translating row 82/91
# Translating row 83/91
# Translating row 84/91
# Translating row 85/91
# Translating row 86/91
# Translating row 87/91
# Translating row 88/91
# Translating row 89/91
# Translating row 90/91
# Translating row 91/91
#
#  Saved translated CSV: BTA_news_combined_master_gem.csv

# %%
#MD vers.
from google import genai
from google.genai import types
from time import sleep
import os
import glob

client = genai.Client(api_key="") #api key here 

INPUT_DIR = "1tv_news_articles_ge"
OUTPUT_DIR = "1tv_news_articles_gem"

def translate_text(text, model="gemini-3-flash-preview"):
    try:
        response = client.models.generate_content(
            model=model,
            contents=f"Please translate the following Georgian content：{text}",
            config=types.GenerateContentConfig(
                temperature=0.3,
                system_instruction="You are a professional translator，please translate from Georgian to English while preserving the Markdown structure and formatting.",
            )
        )
        translated_content = response.text if response.text else ""
        return translated_content.replace("Please translate the following Georgian content:", "").strip()
    
    except Exception as e:
        print(f"Translation error: {e}")
        return ""


def translate_single_file(input_file, output_file, model="gemini-3-flash-preview"):

    print(f"\n Starting to process files: {os.path.basename(input_file)}")

    with open(input_file, "r", encoding = "utf-8") as f:
        content = f.read()

    if not content.strip():
        print("  File is empty.")
        return

    translated_content = translate_text(content, model)

    with open(output_file, "w", encoding = "utf-8") as f:
        f.write(translated_content)

    print(f"  Saved translated file: {os.path.basename(output_file)}")


def translate_all_files(model="gemini-3-flash-preview"):

    #Create output directory if it doesn't exist
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # Find all files
    pattern = os.path.join(INPUT_DIR, "*.md")
    files = glob.glob(pattern)
    
    if not files:
        print(f"No file found！Please check directory: {INPUT_DIR}")
        return
    
    print(f"Found {len(files)} files to translate")
    print(f"Using model: {model}")
    
    for i, input_file in enumerate(files, 1):
        print(f"\n========== Processing {i}/{len(files)} files ==========")
        
        # Create file names
        base_name = os.path.basename(input_file)
        output_name = base_name.replace('.md', f'_{model}_translated.md')
        output_file = os.path.join(OUTPUT_DIR, output_name)
        
        # Translate file
        translate_single_file(input_file, output_file, model)

        sleep(1)
        
    print(f"\n All files translated！Saved at: {OUTPUT_DIR}")


if __name__ == "__main__":

    translate_all_files(model="gemini-3-flash-preview")
# Out:
# Found 10 files to translate
# Using model: gemini-3-flash-preview
#
# ========== Processing 1/10 files ==========
#
#  Starting to process files: tbilisi_offers_free_metro.md
#   Saved translated file: tbilisi_offers_free_metro_gemini-3-flash-preview_translated.md
#
# ========== Processing 2/10 files ==========
#
#  Starting to process files: deputy_economy_minister_10_04_26.md
#   Saved translated file: deputy_economy_minister_10_04_26_gemini-3-flash-preview_translated.md
#
# ========== Processing 3/10 files ==========
#
#  Starting to process files: vespers_of_the_descent.md
#   Saved translated file: vespers_of_the_descent_gemini-3-flash-preview_translated.md
#
# ========== Processing 4/10 files ==========
#
#  Starting to process files: good_friday.md
#   Saved translated file: good_friday_gemini-3-flash-preview_translated.md
#
# ========== Processing 5/10 files ==========
#
#  Starting to process files: metropolitan_shio.md
#   Saved translated file: metropolitan_shio_gemini-3-flash-preview_translated.md
#
# ========== Processing 6/10 files ==========
#
#  Starting to process files: georgia_to_recognise.md
#   Saved translated file: georgia_to_recognise_gemini-3-flash-preview_translated.md
#
# ========== Processing 7/10 files ==========
#
#  Starting to process files: people's_power's.md
#   Saved translated file: people's_power's_gemini-3-flash-preview_translated.md
#
# ========== Processing 8/10 files ==========
#
#  Starting to process files: water_polo.md
#   Saved translated file: water_polo_gemini-3-flash-preview_translated.md
#
# ========== Processing 9/10 files ==========
#
#  Starting to process files: vehicle_movement.md
#   Saved translated file: vehicle_movement_gemini-3-flash-preview_translated.md
#
# ========== Processing 10/10 files ==========
#
#  Starting to process files: trailers_and_semi-trailers.md
#   Saved translated file: trailers_and_semi-trailers_gemini-3-flash-preview_translated.md
#
#  All files translated！Saved at: 1tv_news_articles_gem

# %%
# %pip install --upgrade google-cloud-translate
# Out:
# Collecting google-cloud-translate
#   Using cached google_cloud_translate-3.26.0-py3-none-any.whl.metadata (9.7 kB)
# Collecting google-api-core<3.0.0,>=2.11.0 (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-translate)
#   Using cached google_api_core-2.30.3-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-cloud-translate) (2.52.0)
# Collecting google-cloud-core<3.0.0,>=2.0.0 (from google-cloud-translate)
#   Downloading google_cloud_core-2.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-cloud-translate) (1.80.0)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-cloud-translate)
#   Downloading proto_plus-1.28.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-cloud-translate) (7.34.1)
# Collecting grpc-google-iam-v1<1.0.0,>=0.14.0 (from google-cloud-translate)
#   Using cached grpc_google_iam_v1-0.14.4-py3-none-any.whl.metadata (9.1 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.63.2 (from google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-translate)
#   Downloading googleapis_common_protos-1.75.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-translate) (2.32.5)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-translate)
#   Using cached grpcio_status-1.80.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate) (48.0.0)
# Requirement already satisfied: typing-extensions~=4.12 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from grpcio<2.0.0,>=1.33.2->google-cloud-translate) (4.15.0)
# Collecting protobuf<8.0.0,>=4.25.8 (from google-cloud-translate)
#   Using cached protobuf-6.33.6-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.20.0->google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-translate) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.20.0->google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-translate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.20.0->google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-translate) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.20.0->google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-translate) (2026.2.25)
# Requirement already satisfied: cffi>=2.0.0 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate) (2.0.0)
# Requirement already satisfied: pycparser in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/jessie_guo/miniconda3/envs/Python3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate) (0.6.3)
# Using cached google_cloud_translate-3.26.0-py3-none-any.whl (210 kB)
# Using cached google_api_core-2.30.3-py3-none-any.whl (173 kB)
# Downloading google_cloud_core-2.6.0-py3-none-any.whl (29 kB)
# Downloading googleapis_common_protos-1.75.0-py3-none-any.whl (300 kB)
# Using cached grpc_google_iam_v1-0.14.4-py3-none-any.whl (32 kB)
# Using cached grpcio_status-1.80.0-py3-none-any.whl (14 kB)
# Downloading proto_plus-1.28.0-py3-none-any.whl (50 kB)
# Using cached protobuf-6.33.6-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Installing collected packages: protobuf, proto-plus, googleapis-common-protos, grpcio-status, grpc-google-iam-v1, google-api-core, google-cloud-core, google-cloud-translate
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 7.34.1
#     Uninstalling protobuf-7.34.1:
#       Successfully uninstalled protobuf-7.34.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [google-cloud-translate]e-cloud-translate]
# Successfully installed google-api-core-2.30.3 google-cloud-core-2.6.0 google-cloud-translate-3.26.0 googleapis-common-protos-1.75.0 grpc-google-iam-v1-0.14.4 grpcio-status-1.80.0 proto-plus-1.28.0 protobuf-6.33.6
# Note: you may need to restart the kernel to use updated packages.

# %%
#CSV vers.
import os
import glob
from time import sleep
from google.cloud import translate_v3 as translate

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = ""

PROJECT_ID = ""
LOCATION = "global"  # 'global' is standard unless you use specific regional endpoints

INPUT_DIR = "Data/Bulgarian/BulgarianNews/bul_origianl_BTA_news"
INPUT_FILE = "BTA_news_combined_master_bul.csv"
OUTPUT_DIR = "Data/Bulgarian/BulgarianNews/ggl_BTA_news"
OUTPUT_CSV = "BTA_news_combined_master_ggl.csv"


client = translate.TranslationServiceClient()
parent = f"projects/{PROJECT_ID}/locations/{LOCATION}"

def translate_text(text, target_lang="en", source_lang="bg"):
    """Translates text using the Advanced (v3) API."""
    try:
        # V3 requires a list of strings, even for one translation
        response = client.translate_text(
            request={
                "parent": parent,
                "contents": [text],
                "mime_type": "text/plain",  # Use "text/html" if you have complex Markdown
                "source_language_code": source_lang,
                "target_language_code": target_lang,
            }
        )

        # Extract the translation from the response object
        return response.translations[0].translated_text
    
    except Exception as e:
        print(f"Translation error: {e}")
        return ""

def translate_csv():
    df = pd.read_csv(os.path.join(INPUT_DIR, INPUT_FILE))
    
    translations = []

    print(f"Loaded {len(df)} rows from {INPUT_FILE}")

    for i, text in enumerate(df['Content'], 1):
        print(f"Translating row {i}/{len(df)}")

        if pd.isna(text) or not str(text).strip():
            translations.append("")
            continue

        translated_content = translate_text(str(text))
        translations.append(translated_content)

        sleep(1)

    df["Translated Content"] = translations
    df.to_csv(os.path.join(OUTPUT_DIR, OUTPUT_CSV), index = False)
    print(f"\n Saved translated CSV: {OUTPUT_CSV}")

    return df

if __name__ == "__main__":

    translate_csv()
# Out:
# Loaded 91 rows from BTA_news_combined_master_bul.csv
# Translating row 1/91
# Translating row 2/91
# Translating row 3/91
# Translating row 4/91
# Translating row 5/91
# Translating row 6/91
# Translating row 7/91
# Translating row 8/91
# Translating row 9/91
# Translating row 10/91
# Translating row 11/91
# Translating row 12/91
# Translating row 13/91
# Translating row 14/91
# Translating row 15/91
# Translating row 16/91
# Translating row 17/91
# Translating row 18/91
# Translating row 19/91
# Translating row 20/91
# Translating row 21/91
# Translating row 22/91
# Translating row 23/91
# Translating row 24/91
# Translating row 25/91
# Translating row 26/91
# Translating row 27/91
# Translating row 28/91
# Translating row 29/91
# Translating row 30/91
# Translating row 31/91
# Translating row 32/91
# Translating row 33/91
# Translating row 34/91
# Translating row 35/91
# Translating row 36/91
# Translating row 37/91
# Translating row 38/91
# Translating row 39/91
# Translating row 40/91
# Translating row 41/91
# Translating row 42/91
# Translating row 43/91
# Translating row 44/91
# Translating row 45/91
# Translating row 46/91
# Translating row 47/91
# Translating row 48/91
# Translating row 49/91
# Translating row 50/91
# Translating row 51/91
# Translating row 52/91
# Translating row 53/91
# Translating row 54/91
# Translating row 55/91
# Translating row 56/91
# Translating row 57/91
# Translating row 58/91
# Translating row 59/91
# Translating row 60/91
# Translating row 61/91
# Translating row 62/91
# Translating row 63/91
# Translating row 64/91
# Translating row 65/91
# Translating row 66/91
# Translating row 67/91
# Translating row 68/91
# Translating row 69/91
# Translating row 70/91
# Translating row 71/91
# Translating row 72/91
# Translating row 73/91
# Translating row 74/91
# Translating row 75/91
# Translating row 76/91
# Translating row 77/91
# Translating row 78/91
# Translating row 79/91
# Translating row 80/91
# Translating row 81/91
# Translating row 82/91
# Translating row 83/91
# Translating row 84/91
# Translating row 85/91
# Translating row 86/91
# Translating row 87/91
# Translating row 88/91
# Translating row 89/91
# Translating row 90/91
# Translating row 91/91
#
#  Saved translated CSV: BTA_news_combined_master_ggl.csv

# %%
#MD Vers.
import os
import glob
from time import sleep
from google.cloud import translate_v3 as translate

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "" #key

PROJECT_ID = ""
LOCATION = "global"  # 'global' is standard unless you use specific regional endpoints

INPUT_DIR = "1tv_news_articles_ge"
OUTPUT_DIR = "1tv_news_articles_ggl"

client = translate.TranslationServiceClient()
parent = f"projects/{PROJECT_ID}/locations/{LOCATION}"

def translate_text(text, target_lang="en", source_lang="ka"):
    """Translates text using the Advanced (v3) API."""
    try:
        # V3 requires a list of strings, even for one translation
        response = client.translate_text(
            request={
                "parent": parent,
                "contents": [text],
                "mime_type": "text/plain",  # Use "text/html" if you have complex Markdown
                "source_language_code": source_lang,
                "target_language_code": target_lang,
            }
        )

        # Extract the translation from the response object
        return response.translations[0].translated_text
    
    except Exception as e:
        print(f"Translation error: {e}")
        return ""

def translate_single_file(input_file, output_file):
    print(f"\n Starting to process: {os.path.basename(input_file)}")

    with open(input_file, "r", encoding="utf-8") as f:
        content = f.read()

    if not content.strip():
        print("  File is empty.")
        return

    translated_content = translate_text(content)

    if translated_content:
        with open(output_file, "w", encoding="utf-8") as f:
            f.write(translated_content)
        print(f"  Saved translated file: {os.path.basename(output_file)}")
    else:
        print("  Failed to translate.")

def translate_all_files():
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    pattern = os.path.join(INPUT_DIR, "*.md")
    files = glob.glob(pattern)
    
    if not files:
        print(f"No files found in {INPUT_DIR}")
        return
    
    print(f"Found {len(files)} files. Using Cloud Translation Advanced (v3)...")
    
    for i, input_file in enumerate(files, 1):
        print(f"\n========== {i}/{len(files)} ==========")
        base_name = os.path.basename(input_file)
        output_name = base_name.replace('.md', '_ggl_translated.md')
        output_file = os.path.join(OUTPUT_DIR, output_name)
        
        translate_single_file(input_file, output_file)
        sleep(0.1)

if __name__ == "__main__":
    translate_all_files()
# Out:
# Found 10 files. Using Cloud Translation Advanced (v3)...
#
# ========== 1/10 ==========
#
#  Starting to process: tbilisi_offers_free_metro.md
#   Saved translated file: tbilisi_offers_free_metro_ggl_translated.md
#
# ========== 2/10 ==========
#
#  Starting to process: deputy_economy_minister_10_04_26.md
#   Saved translated file: deputy_economy_minister_10_04_26_ggl_translated.md
#
# ========== 3/10 ==========
#
#  Starting to process: vespers_of_the_descent.md
#   Saved translated file: vespers_of_the_descent_ggl_translated.md
#
# ========== 4/10 ==========
#
#  Starting to process: good_friday.md
#   Saved translated file: good_friday_ggl_translated.md
#
# ========== 5/10 ==========
#
#  Starting to process: metropolitan_shio.md
#   Saved translated file: metropolitan_shio_ggl_translated.md
#
# ========== 6/10 ==========
#
#  Starting to process: georgia_to_recognise.md
#   Saved translated file: georgia_to_recognise_ggl_translated.md
#
# ========== 7/10 ==========
#
#  Starting to process: people's_power's.md
#   Saved translated file: people's_power's_ggl_translated.md
#
# ========== 8/10 ==========
#
#  Starting to process: water_polo.md
#   Saved translated file: water_polo_ggl_translated.md
#
# ========== 9/10 ==========
#
#  Starting to process: vehicle_movement.md
#   Saved translated file: vehicle_movement_ggl_translated.md
#
# ========== 10/10 ==========
#
#  Starting to process: trailers_and_semi-trailers.md
#   Saved translated file: trailers_and_semi-trailers_ggl_translated.md
